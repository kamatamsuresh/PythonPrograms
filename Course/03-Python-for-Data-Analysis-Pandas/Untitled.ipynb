# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.read_csv('test')

# %%
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6

# %%
df.to_csv('testout',index=False)

# %%
pf = pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')

# %%
pf.to_excel('Excel_Sample.xlsx',sheet_name='Shee1')

# %%
df = pd.read_html('https://www.isb.edu/pgp/learning-model/corecourses')

# %%
df[0]
# Out:
#                                          Course Title  \
# 0                    TERM 1: APRIL 23 - JUNE 03, 2018
# 1            FINANCIAL ACCOUNTING AND DECISION MAKING
# 2                                MANAGERIAL ECONOMICS
# 3                                MARKETING MANAGEMENT
# 4        STATISTICAL METHODS FOR MANAGEMENT DECISIONS
# 5                    TERM-2: JUNE 04 - JULY 15, 2018​
# 6                              BUSINESS COMMUNICATION
# 7                                COMPETITIVE STRATEGY
# 8                    DECISION MODELS AND OPTIMISATION
# 9                                    GLOBAL ECONOMICS
# 10                          MARKETING DECISION MAKING
# 11                TERM 3: JULY 167 - AUGUST 26, 2018​
# 12                                CORPORATE FINANCE I
# 13          MANAGERIAL ACCOUNTING AND DECISION MAKING
# 14                        MANAGEMENT OF ORGANIZATIONS
# 15                              OPERATIONS MANAGEMENT
# ...

# %%
from sqlalchemy import create_engine
